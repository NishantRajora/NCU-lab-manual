# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %%
print("----- XGBoost on Iris Dataset -----")

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

model1 = XGBClassifier()

model1.fit(X_train, y_train)

y_pred = model1.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy (Iris Dataset):", accuracy)
# Out:
# ----- XGBoost on Iris Dataset -----
# Accuracy (Iris Dataset): 1.0

# %%
print("\n----- XGBoost on Breast Cancer Dataset -----")

cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

model2 = XGBClassifier()

model2.fit(X_train, y_train)

y_pred = model2.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy (Breast Cancer Dataset):", accuracy)
# Out:
# ----- XGBoost on Breast Cancer Dataset -----
# Accuracy (Breast Cancer Dataset): 0.9649122807017544
